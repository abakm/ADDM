# %% [markdown]
# <a href="https://colab.research.google.com/github/abakm/ADDM/blob/master/RegressionAssignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


# Read CSV
df = pd.read_csv("./insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #Data Exploration

# %%
# Basic Information
print(f"Number of records: {df.shape[0]}")
print(f"Number of features: {df.shape[1]}")
print(f"nFeature Details:", df.info())
# Out:
# Number of records: 1338
# Number of features: 7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# nFeature Details: None

# %%
# statistica Summary
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# #### Univariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 10))
sns.histplot(x=df["age"], color="red")
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x=df["bmi"], palette='pastel')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('BMI Distribution')
plt.show()
# Out:
# <ipython-input-370-b0fa8ba22294>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["bmi"], palette='pastel')

# %% [markdown]
# #### Categorical Analysis

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["sex"], palette='pastel')
plt.xlabel('sex')
plt.ylabel('Frequency')
plt.title('sex Distribution')
plt.show()
# Out:
# <ipython-input-371-12fca0722298>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["sex"], palette='pastel')

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["children"], palette='pastel')
plt.xlabel('Children')
plt.ylabel('Frequency')
plt.title('Children Distribution')
plt.show()
# Out:
# <ipython-input-372-b2d14b1f2d99>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["children"], palette='pastel')

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["smoker"], palette='pastel')
plt.xlabel('Smoker')
plt.ylabel('Frequency')
plt.title('Smoker Distribution')
plt.show()
# Out:
# <ipython-input-373-1f6b4d43a3df>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["smoker"], palette='pastel')

# %%
plt.figure(figsize=(10, 10))
sns.countplot(x=df["region"], palette='pastel')
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Region Distribution')
plt.show()
# Out:
# <ipython-input-374-a0e98ed69ae5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["region"], palette='pastel')

# %% [markdown]
# ### Bivariate Analysis

# %%
import seaborn as sns
plt.figure(figsize=(5,3))
sns.scatterplot(x='age', y='charges', hue="smoker", data=df, color='r')
plt.xlabel('Age')
plt.ylabel('charges')
plt.title('Age vs charges')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(5,3))
sns.scatterplot(x='age', y='charges', hue="children", data=df, color='r')
plt.xlabel('Age')
plt.ylabel('charges')
plt.title('Age vs charges')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(5,3))
sns.scatterplot(x='age', y='charges', hue="region", data=df, color='r')
plt.xlabel('Age')
plt.ylabel('charges')
plt.title('Age vs charges')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(5,3))
sns.scatterplot(x='bmi', y='charges', hue="age", data=df, color='blue')
plt.xlabel('bmi')
plt.ylabel('charges')
plt.title('bmi vs charges')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(5,3))
sns.scatterplot(x='smoker', y='charges', hue="age", data=df, color='blue')
plt.xlabel('bmi')
plt.ylabel('charges')
plt.title('bmi vs charges')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Drop Duplicates
df.drop_duplicates(inplace=True)
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.isnull().sum()  # checking for null values
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# Apply Label Encoding to sex, smoker and region

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# Apply Label Encoding to the 'sex' column
df["sex"] = label_encoder.fit_transform(df["sex"])
df["smoker"] = label_encoder.fit_transform(df["smoker"])
df["region"] = label_encoder.fit_transform(df["region"])

df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %%
df.dropna(inplace=True)
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1337 rows x 7 columns]

# %% [markdown]
# ## Model Development

# %%
# set Independent and dependent variable
x = df[["age", "sex", "bmi", "children", "smoker", "region"]]
y = df["charges"]

# %%
# traing sets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# create the model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Prediction
model.predict(x_test)
# Out:
# array([ 8.08045019e+03,  5.59287112e+03,  1.43782987e+04,  3.17318195e+04,
#         9.15835694e+03,  1.33610143e+04,  3.02576553e+04,  1.30864736e+03,
#         1.08494254e+04,  1.13755485e+04,  1.04822214e+04,  3.31558608e+04,
#         3.09123841e+04,  1.71688443e+04,  1.06361393e+04,  9.37424715e+03,
#         3.96524338e+03,  3.19229863e+04,  3.08468457e+03,  5.47544373e+03,
#         3.76844305e+03,  3.01552667e+04,  1.50768984e+04,  3.02746510e+04,
#         3.10830548e+04,  5.52001772e+03,  3.56655758e+04,  3.63713163e+04,
#         1.12979802e+04,  1.40664742e+04,  6.37519963e+03,  1.29381095e+04,
#         6.79284837e+02,  1.19476924e+04,  3.97832706e+04,  1.21517558e+04,
#         4.57717842e+03,  4.01652351e+03,  3.11475453e+04,  9.22301501e+03,
#         6.86852604e+03,  3.00358113e+04,  3.49732855e+04,  1.21709787e+04,
#         7.46262777e+03,  3.27014535e+03,  6.02195905e+03,  8.81742438e+03,
# ...

# %% [markdown]
# ## Evaluate the model's performance

# %%
# Calculate mean_sqaured_error
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(x_test)
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 35493102.61165051

# %% [markdown]
# The MSE represents the average of the squared differences between your model's predictions and the actual values. A value of 35493102.61165051 indicates that, on average, the squared error in your predictions is quite large.
#
# Remember that the units of MSE are the squared units of your target variable. So, if you were predicting something like insurance costs in dollars, this MSE would be in dollars squared. This can make direct interpretation of the magnitude a bit challenging.
