# %% [markdown]
# <a href="https://colab.research.google.com/github/abakm/ADDM/blob/master/assighment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###  1.Read the dataset to python environment

# %%
import pandas as pd

df = pd.read_csv('diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### 2. Display the columns in the dataset.

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# ###  3. Calculate the mean of each column of the dataset.

# %%
for column in df.columns:
  print(f"\nColumn:{column}, Mean: {df[column].mean()} Median: {df[column].median()} Mode: {df[column].mode()}")
# Out:
# Column:Pregnancies, Mean: 3.8450520833333335 Median: 3.0 Mode: 0    1
# Name: Pregnancies, dtype: int64
#
# Column:Glucose, Mean: 120.89453125 Median: 117.0 Mode: 0     99
# 1    100
# Name: Glucose, dtype: int64
#
# Column:BloodPressure, Mean: 69.10546875 Median: 72.0 Mode: 0    70
# Name: BloodPressure, dtype: int64
#
# Column:SkinThickness, Mean: 20.536458333333332 Median: 23.0 Mode: 0    0
# Name: SkinThickness, dtype: int64
#
# Column:Insulin, Mean: 79.79947916666667 Median: 30.5 Mode: 0    0
# Name: Insulin, dtype: int64
#
# Column:BMI, Mean: 31.992578124999998 Median: 32.0 Mode: 0    32.0
# Name: BMI, dtype: float64
#
# Column:DiabetesPedigreeFunction, Mean: 0.47187630208333325 Median: 0.3725 Mode: 0    0.254
# 1    0.258
# Name: DiabetesPedigreeFunction, dtype: float64
#
# Column:Age, Mean: 33.240885416666664 Median: 29.0 Mode: 0    22
# Name: Age, dtype: int64
#
# Column:Outcome, Mean: 0.3489583333333333 Median: 0.0 Mode: 0    0
# Name: Outcome, dtype: int64

# %% [markdown]
# ## 4. Check for the null values present in the dataset

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### 5. Perform meaningful visualizations using the dataset. Bring at least 3 visualizations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Univariate Analysis
plt.figure(figsize=(5,3))
plt.hist(df['Pregnancies'], color='red')
plt.xlabel('Pregnancies')
plt.ylabel('Frequency')
plt.title('Glucose Distribution')
plt.show()


# Bivariate Analysis num vs num , Scatterplot
sns.scatterplot(x='Pregnancies', y='SkinThickness', data=df, color='r')
plt.xlabel('Pregnancies')
plt.ylabel('SkinThickness')
plt.title('Pregnancies vs SkinThickness')
plt.show()


# Categorical Analysis
sns.countplot(x='Outcome', data=df, palette='Set2')
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.title('Outcome Distribution')
plt.show()

# Bivariate Analysis num vs categorical , Boxplot
sns.boxplot(x='Outcome', y='Glucose', data=df, palette='Set2')
plt.xlabel('Outcome')
plt.ylabel('Glucose')
plt.title('Glucose Distribution by Outcome')
plt.show()
# Out:
# <ipython-input-25-b40b9432b3b7>:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Outcome', data=df, palette='Set2')
# <ipython-input-25-b40b9432b3b7>:29: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outcome', y='Glucose', data=df, palette='Set2')
